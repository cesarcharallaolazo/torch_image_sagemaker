# %%
from sagemaker.pytorch import PyTorchModel
from sagemaker import get_execution_role

role = get_execution_role() 


pytorch_model = PyTorchModel(model_data='s3://sagemaker-us-east-1-428881646170/sagemaker/local-pytorch-example/model.tar.gz', 
                             role=role, entry_point='inference.py', 
                             py_version='py3',
                             framework_version='1.7.1')
predictor = pytorch_model.deploy(instance_type='ml.c4.xlarge', initial_instance_count=1)

print(predictor.endpoint_name) # get endpoint name for downstream usage
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/py38_xgb120/lib/python3.8/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     169     with S3Transfer(self, Config) as transfer:
# --> 170         return transfer.download_file(
#     171             bucket=Bucket, key=Key, filename=Filename,
#
# ~/anaconda3/envs/py38_xgb120/lib/python3.8/site-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     306         try:
# --> 307             future.result()
#     308         # This is for backwards compatibility where when retries are
#
# ~/anaconda3/envs/py38_xgb120/lib/python3.8/site-packages/s3transfer/futures.py in result(self)
#     108             self.cancel()
# --> 109             raise e
#     110
#
# ...
